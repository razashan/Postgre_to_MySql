# %%
import psycopg2 as pg
import pymysql
import pandas.io.sql as psql
from sqlalchemy import create_engine

# %%
my_conn = create_engine("mysql+mysqldb://root:admin@localhost/sakila")

# %%
import pandas as pd 
df = pd.read_csv('Test_Data.csv')
df.head()
# Out:
#    incident_number                      instanceid  status  login_id  \
# 0  INC000009548218  IDGAA5V0F6OZ6AR5W8Y2R4WZ0H0KCN  Closed  80087807
# 1  INC000009548341  IDGAA5V0F7SKFAR5W7W4R4WXPCRJKI  Closed  80087807
# 2  INC000009547807  IDGAA5V0F7SKFAR5WHZSR4WNS6PG7R  Closed  80087135
# 3  INC000009547804  IDGAA5V0F7SKFAR5WHLTR4WN47PCBY  Closed  80087135
# 4  INC000009547798  IDGAA5V0F7SKFAR5WHFVR4WMYKOZ3M  Closed  80087135
#
#    submitter   submitdate   assigned_group  assignee_login_id   owner_group  \
# 0   80087807  44773.96961     IGW Cisco FO           80087807  IGW Cisco FO
# 1   80087807  44773.95383  FSN-SYSTEMS-CIS           80062296  IGW Cisco FO
# 2   80087135  44773.80558      Maintenance           80087135  EDN Cisco FO
# 3   80087135  44773.79966     EDN Cisco FO           80087135  EDN Cisco FO
# 4   80087135  44773.79310     EDN Cisco FO           80087136  EDN Cisco FO
#
#   last_modified_by  ...  ccnode_b  ccservice_type cclink_capacity  \
# 0         80087138  ...       NaN             NaN             NaN
# 1     AR_ESCALATOR  ...       NaN             NaN             NaN
# 2     AR_ESCALATOR  ...       NaN             NaN             NaN
# 3     AR_ESCALATOR  ...       NaN             NaN             NaN
# 4     AR_ESCALATOR  ...       NaN             NaN             NaN
#
#    ccnumber_of_e1s  ccnumber_of_ges  ccnumber_of_pon_ports  \
# 0              NaN              NaN                    NaN
# 1              NaN              NaN                    NaN
# 2              NaN              NaN                    NaN
# 3              NaN              NaN                    NaN
# 4              NaN              NaN                    NaN
#
#   ccactual_service_impact ccfm_reported_date ccfm_resolution_date  \
# 0                       1        44773.96667          44773.96736
# 1                       1        44773.95278          44773.97083
# 2                       1        44773.79722          44773.93750
# 3                       1        44773.79653          44773.80694
# 4                       1        44773.78264          44774.63750
#
#             vendor_group
# 0  International carrier
# 1   FSN-SYSTEMS-CIS Team
# 2       Maintenance Team
# 3             Power Team
# 4               PMP Team
#
# [5 rows x 116 columns]

# %%
df.to_sql(con=my_conn,name='excel1',if_exists='append',index=False)
